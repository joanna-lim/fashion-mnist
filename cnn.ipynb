# %%
import torch
import torchvision
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Getting the MNIST Dataset

# %%
mnist_fashion_dataset = torchvision.datasets.FashionMNIST(root='./data', train=True, download=True, transform=None)
data = mnist_fashion_dataset.data
targets = mnist_fashion_dataset.targets

data = data.reshape(-1, 28*28)
X_train, X_test, y_train, y_test = train_test_split(data, targets, test_size=0.2, random_state=42)

train_df = pd.DataFrame(X_train.numpy(), columns=[f"pixel_{i}" for i in range(28*28)])
train_df['label'] = y_train.numpy()

test_df = pd.DataFrame(X_test.numpy(), columns=[f"pixel_{i}" for i in range(28*28)])
test_df['label'] = y_test.numpy()

train_df.to_csv('train.csv', index=False)
test_df.to_csv('test.csv', index=False)

# %%
# plot the first few images
for i in range(9):
    plt.subplot(330 + 1 + i)
    image = np.array(X_train[i]).reshape(28, 28)
    plt.imshow(image, cmap=plt.get_cmap('gray'))
    plt.axis('off') 
plt.show()
